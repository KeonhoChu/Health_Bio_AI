# %% [markdown]
# # Paper: Deep learning for ECG segmentation
#
# - Moskalenko, Viktor, Nikolai Zolotykh, and Grigory Osipov. "Deep learning for ECG segmentation." International conference on neuroinformatics. Springer, Cham, 2019.

# %% [markdown]
# ### 00. 필요한 라이브러리 임포트

# %%
import numpy as np
import tensorflow as tf

# 데이터 전처리를 위한 라이브러리
import json
from scipy.signal import butter, lfilter, medfilt

# 모델 학습을 위한 라이브러리
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, BatchNormalization, MaxPooling1D
from tensorflow.keras.layers import Conv1DTranspose, concatenate, Activation, SpatialDropout1D

# 성능평가 함수를 위한 라이브러리
from tensorflow.keras import backend as K

# 시각화를 위한 라이브러리
from tqdm import tqdm
import matplotlib.pyplot as plt

# %% [markdown]
# ### 01. 데이터 불러오기

# %%
# 변수 정의하기
# variables
leads_names = ['i', 'ii', 'iii', 'avr', 'avl', 'avf', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6']
FREQUENCY_OF_DATASET = 500

num_classes = 4 # P, qrs, t, background

leads = 12

# %%
"""
Code Source
https://github.com/Namenaro/ecg_segmentation
(Paper : ECG Segmentation by Neural Networks : Errors and Correction)

Read LUDB dataset (json file)
"""
def load_raw_dataset(raw_dataset):
    '''
    1. 입력 변수
        raw_dataset: 데이터 셋이 들어옵니다.
    
    2. 출력 변수
        데이터라벨링이 끝나면, 넘파이 배열로 만들어 준 후, array의 1축과 2축의 위치를 바꾸어 준다.
        마지막으로 딕셔너리의 형태로 데이터와 마스크를 리턴한다.
        
    3. 데이터를 불러오는 함수입니다.
    '''
    with open(raw_dataset, 'r') as f:
        data = json.load(f)
    X=[]
    Y=[]
    for case_id in data.keys():
        leads = data[case_id]['Leads']
        x = []
        y = []
        for i in range(len(leads_names)):
            lead_name = leads_names[i]
            tmp = leads[lead_name]['Signal']
            tmp = np.asarray(tmp, dtype=np.float64)
            tmp = tmp / 1000. # -> scaling 이유: 정규화 (단위 변경: mV --> uV)
            x.append(tmp)

        # 각 P, QRS, T, Background 레이블 데이터 (마스크) 생성
        signal_len = 5000    # 총 10초
        delineation_tables = leads[leads_names[0]]['DelineationDoc']
        p_delin = delineation_tables['p']
        qrs_delin = delineation_tables['qrs']
        t_delin = delineation_tables['t']

        p = get_mask(p_delin, signal_len)
        qrs = get_mask(qrs_delin, signal_len)
        t = get_mask(t_delin, signal_len)
        background = get_background(p, qrs, t)

        y.append(background)
        y.append(p)
        y.append(qrs)
        y.append(t)

        X.append(x)
        Y.append(y)

    X = np.array(X)
    X = np.swapaxes(X, 1, 2)

    Y = np.array(Y)
    Y = np.swapaxes(Y, 1, 2)

    return {"x":X, "y":Y}

def get_mask(table, length):
    '''
    정답을 달아 주는 함수
    '''
    mask = [0] * length
    for triplet in table:
        start = triplet[0]
        end = triplet[2] + 1
        for i in range(start, end, 1):
            mask[i] = 1
    return mask

def get_background(p, qrs, t):
    '''
    p, qrs, t가 아닌 부분을 체크
    '''
    background = np.zeros_like(p)
    for i in range(len(p)):
        if p[i] == 0 and qrs[i] == 0 and t[i] == 0:
            background[i] = 1
    return background

# %% [markdown]
# ### 02. 데이터 전처리 함수: 잡음 제거

# %%
def LPF(data, fs_= 500, highcut = 40, order = 5):
    """
    1. 입력 변수
    data : 데이터셋 ("ecg_data_200.json")
    fs_ : sample data frequency(샘플링 주파수 1초 : 500) -> 500 samples/sec = 500 Hz
    highcut : 저주파만 통과시키기 위한 제한 수치 ([0, 40] Hz)
    order : 필터 계수, 높을수록 민감 (frequency를 얼마나 급격하게 자를 것인지)
    
    2. 출력 변수
    LPF 필터링된 신호
    
    3. Low Pass Filter : LPF는 저주파는 통과시키고 고주파는 거릅니다.
    """
    nyq = 0.5 * fs_
    high = highcut / nyq
    b, a = butter(order, high, btype='lowpass') # b, a가 먼지
    
    # (최고 구간(0< low < 1))
    return lfilter(b, a, data)

# %%
# 2개의 중간값 필터를 이용하여 de-trending 하는 코드
def get_median_filter_width(sampling_rate, duration):
    res = int( sampling_rate*duration )
    res += ((res%2) - 1) # needs to be an odd number
    return res

# baseline fitting by filtering
# === Define Filtering Params for Baseline fitting Leads======================
ms_flt_array = [0.2, 0.6]    #<-- length of baseline fitting filters (in seconds)
mfa = np.zeros(len(ms_flt_array), dtype='int')
for i in range(0, len(ms_flt_array)):
    mfa[i] = get_median_filter_width(500, ms_flt_array[i])
    # 99, 299


def filter_signal(X):
    global mfa
    X0 = X  #read orignal signal
    for mi in range(0,len(mfa)):
        X0 = medfilt(X0, mfa[mi]) # apply median filter one by one on top of each other
    X0 = np.subtract(X, X0)  # finally subtract from orignal signal
    return X0

# %%
# 최종적으로 잡음 제거하는 코드
def Denoise(dataset):
    for patient in tqdm(range(200)):
        for lead in range(12):
            dataset['x'][patient, :, lead] = filter_signal(LPF(dataset['x'][patient, :, lead]))

# %% [markdown]
# ### 03. 데이터 증강하기

# %%
def augmentation(dataset, ratio = 0.8):
    """
    Input
        - dataset: dictionary 형태의 ECG 및 label 데이터
        - ratio: training과 validation set에 대한 비율
    
    Task
        1. training set과 validation set으로 나눈다.
        2. 적은 데이터 수로 인한 과적합을 피하기 위해, 10초 길이의 심전도 신호를 4초 길이로 잘라 augmentation을 한다.
    """
    # 1. Shuffle
    # ECG dataset shape : (200, 5000, 12)
    # Label shape : (200, 5000, 4)

    train_idx = int(200 * ratio)  # 80%를 트레인세트로 분류
    idx = np.arange(200)        # 0 ~ 199
    np.random.shuffle(idx)

    x = dataset["x"][idx]
    y = dataset["y"][idx]

    # 2. Split into 8:2
    tmp_train_x = x[:train_idx]
    tmp_valid_x = x[train_idx:]

    tmp_train_y = y[:train_idx]
    tmp_valid_y = y[train_idx:]

    # 3. Augmentation on Train and Valid dataset
    # step 설명 : 250 (0.5초) 이동하며 4초 신호를 augmentation한다.
    step = 250
    
    N_train = 1500  # 여유있게 범위를 줌
    N_valid = 400

    train_x, train_y = np.zeros((N_train, 2000, 12), dtype=np.float32), np.zeros((N_train, 2000, 4), dtype=np.float32) # 4초
    valid_x, valid_y = np.zeros((N_valid, 2000, 12), dtype=np.float32), np.zeros((N_valid, 2000, 4), dtype=np.float32) 
    # print(N_train, N_valid)
    print("Start Augmentation")

    # 4.1. Train
    t_cnt, v_cnt = 0, 0
    for patient in range(train_idx):
        tmp = tmp_train_y[patient]
        '''
        LUDB database에 처음과 끝 cardiac cycle 부분에는 레이블링이 되어있지 않다. 
        따라서, 실제로 레이블링된 데이터가 있는 부분을 증강하기 위해서 cropping 과정이 필요하다.
        '''
        tmp = np.argmax(tmp[:, 1:], axis=-1) 
        tmp = np.nonzero(tmp)[0]             # argmax 후 0이 아닌 부분에 데이터가 존재 
        start_idx, end_idx = tmp[0], tmp[-1]
        length = end_idx - start_idx + 1

        tmp_x = tmp_train_x[patient, start_idx:end_idx + 1]
        tmp_y = tmp_train_y[patient, start_idx:end_idx + 1]
        for idx in range(0, length-2000, step):        # 원본 10초에서 4초만큼씩 잘라, step 만큼 이동하여 데이터 증강
            train_x[t_cnt] = tmp_x[idx:idx + 2000, :]
            train_y[t_cnt] = tmp_y[idx:idx + 2000, :]
            t_cnt += 1
    print(f"Number of Train set : {t_cnt}")

    # 4.2. Valid
    for patient in range(200-train_idx):
        tmp = tmp_valid_y[patient]
        
        tmp = np.argmax(tmp[:, 1:], axis=-1)
        tmp = np.nonzero(tmp)[0]
        start_idx, end_idx = tmp[0], tmp[-1]
        length = end_idx - start_idx + 1

        tmp_x = tmp_valid_x[patient, start_idx:end_idx + 1]
        tmp_y = tmp_valid_y[patient, start_idx:end_idx + 1]
        for idx in range(0, length-2000, step):
            valid_x[v_cnt] = tmp_x[idx:idx + 2000, :]
            valid_y[v_cnt] = tmp_y[idx:idx + 2000, :]
            v_cnt += 1
    print(f"Number of Valid set : {v_cnt}")

    train_x, train_y = train_x[:t_cnt], train_y[:t_cnt]
    valid_x, valid_y = valid_x[:v_cnt], valid_y[:v_cnt]

    # 5. Shuffle and Save
    print("\nStart saving the dataset...")
    idx = np.arange(t_cnt)
    np.random.shuffle(idx)
    train_x = train_x[idx]
    train_y = train_y[idx]

    np.save(f"train_x", train_x)
    np.save(f"train_y", train_y)

    np.save(f"valid_x", valid_x)
    np.save(f"valid_y", valid_y)
    print("Complete saving\n")

# %% [markdown]
# ### 04. 모델 설계 : U-Net 1D

# %%
def UNet1D():
    num_filter = 16

    inputs = Input((2000, 12))  # length of 4 sec signal is 2,000

    # Encoder
    x = Conv1D(num_filter, 9, kernel_initializer='he_normal', padding='same')(inputs)
    # kernel_initializer : kernel가중치 행렬의 초기화 프로그램입니다( 참조 keras.initializers). 기본값은 'glorot_uniform'입니다.
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    o1 = Activation('relu')(x)
    x = MaxPooling1D(2)(o1)

    x = Conv1D(num_filter*2, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter*2, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    o2 = Activation('relu')(x)
    x = MaxPooling1D(2)(o2)

    x = Conv1D(num_filter*4, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter*4, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    o3 = Activation('relu')(x)
    x = MaxPooling1D(2)(o3)

    x = Conv1D(num_filter*8, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter*8, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    o4 = Activation('relu')(x)
    x = MaxPooling1D(2)(o4)

    x = Conv1D(num_filter*16, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter*16, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)

    # Decoder
    x = Conv1DTranspose(num_filter*8, 8, strides=2, padding='same')(x)
    x = concatenate([x, o4])
    x = Conv1D(num_filter*8, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter*8, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)

    x = Conv1DTranspose(num_filter*4, 8, strides=2, padding='same')(x)
    x = concatenate([x, o3])
    x = Conv1D(num_filter*4, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter*4, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)

    x = Conv1DTranspose(num_filter*2, 8, strides=2, padding='same')(x)
    x = concatenate([x, o2])
    x = Conv1D(num_filter*2, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter*2, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)

    x = Conv1DTranspose(num_filter, 8, strides=2, padding='same')(x)
    x = concatenate([x, o1])
    x = Conv1D(num_filter, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)
    x = Conv1D(num_filter, 9, kernel_initializer='he_normal', padding='same')(x)
    x = BatchNormalization()(x)
    x = SpatialDropout1D(0.3)(x)
    x = Activation('relu')(x)

    outputs = Conv1D(num_classes, 1, activation='softmax', kernel_initializer='he_normal')(x)

    model = Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# ### 05. 성능 평가 함수 정의

# %%
# 1. F1-Score = Dice score
def f1_score(y_true, y_pred):
    smooth = 0.0001
    intersection = K.sum(y_true * y_pred, axis=[1, 2])
    union = K.sum(y_true, axis=[1, 2]) + K.sum(y_pred, axis=[1, 2])
    return K.mean( (2. * intersection + smooth) / (union + smooth), axis=0)

class f1_loss(tf.losses.Loss):
    def __init__(self):
        super(f1_loss, self).__init__(reduction='auto', name="f1_loss")

    def call(self, y_true, y_pred):
        return 1 - f1_score(y_true, y_pred)


# 2. Jaccard = IoU
def Jaccard(y_true, y_pred):
    smooth = 0.0001
    intersection = K.sum(y_true * y_pred, axis=[1, 2])
    union = K.sum(y_true, axis=[1, 2]) + K.sum(y_pred, axis=[1, 2])
    return K.mean((intersection + smooth) / (union - intersection + smooth), axis=0)

class JaccardLoss(tf.losses.Loss):
    def __init__(self):
        super(JaccardLoss, self).__init__(reduction='auto', name="JaccardLoss")

    def call(self, y_true, y_pred):
        return 1 - Jaccard(y_true, y_pred)

# %% [markdown]
# ### 06. 예측 함수 정의

# %%
def Predict(test, n_sample=20):
    '''
    Input
        - test: [valid_x, valid_y]
        - n_sample: 보여줄 샘플 갯수
    테스트셋에 대해서 예측한 결과와 실제 labeling 데이터를 시각화한다.    
    '''
    model = UNet1D()
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.005),
                  loss=f1_loss(),
                  metrics=[Jaccard, f1_score])
    model.load_weights("weights.h5")

    for i, test_ecg in enumerate(test[0]): # valid_x
        pred = model.predict(np.reshape(test_ecg, (1, 2000, 12)))
        true = np.argmax(test[1][i], axis=-1)
        pred = np.argmax(pred[0], axis=-1)

        fig, ax = plt.subplots(3, 1, figsize=(20, 12))

        ax[0].plot(test_ecg[:, 1])
        ax[0].set_title(f"ECG_{i}'s lead II", fontsize=10)

        ax[1].plot(true)
        ax[1].set_title(f"ECG_{i}'s Groud Truth", fontsize=10)

        ax[2].plot(pred)
        ax[2].set_title(f"ECG_{i}'s Prediction", fontsize=10)

        plt.show()
        
        # 20개의 샘플만 보여준 후 멈춤
        if i == n_sample - 1:
            break

# %% [markdown]
# ### 데이터 전처리
#
# #### 이미 전처리된 데이터가 numpy로 저장되어 있다면, 해당 코드 셀은 주석처리하여 실행 안해도 됨.

# %%
# 1. Load dataset
dataset = load_raw_dataset("ecg_data_200.json")

# 2. Preprocessing
Denoise(dataset)

# 3. Augmentation
augmentation(dataset)
del dataset

# %%
train = [np.load("train_x.npy"), np.load("train_y.npy")]
valid = [np.load("valid_x.npy"), np.load("valid_y.npy")]

# %% [markdown]
# ### 모델 학습

# %%
# 4. Model
print("Start Training")
batch_size = 256
lr = 0.005
epochs = 2000

model = UNet1D()
model.summary()

# 5. Train
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
              loss=f1_loss(),
              metrics=[Jaccard, f1_score])

callbacks_list = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath="weights.h5",
        monitor="val_f1_score",
        mode="max",
        save_best_only=True,
        save_weights_only=True,
        verbose=1),

    tf.keras.callbacks.EarlyStopping(
        monitor="val_f1_score",
        min_delta=0.005,
        mode="max",
        patience=10,
        verbose=1),

    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_f1_score',
        factor=0.5,
        patience=5,
        mode='max',
        min_delta=0.01,
        cooldown=0,
        min_lr=0.0001,
        verbose=1)
]

history = model.fit(train[0], train[1],
                    validation_data=(valid[0], valid[1]),
                    callbacks=callbacks_list,
                    epochs=epochs,
                    batch_size=batch_size,
                    shuffle=True,
                    )


loss = history.history['loss']
val_loss = history.history['val_loss']
Jaccard = history.history["Jaccard"]
val_Jaccard = history.history["val_Jaccard"]
f1 = history.history["f1_score"]
val_f1 = history.history["val_f1_score"]

epochs_range = range(len(loss))
fig, ax = plt.subplots(1, 3, figsize = (20, 12))
ax[0].plot(epochs_range, loss, label='Training Loss')
ax[0].plot(epochs_range, val_loss, label='Validation Loss')

ax[1].plot(epochs_range, Jaccard, label='Training Jaccard')
ax[1].plot(epochs_range, val_Jaccard, label='Validation Jaccard')

ax[2].plot(epochs_range, f1, label='Training f1-score')
ax[2].plot(epochs_range, val_f1, label='Validation f1-score')
plt.show()

del model, history, train
# Out:
# Start Training
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 2000, 12)]   0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 2000, 16)     1744        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 2000, 16)     64          conv1d[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d (SpatialDropo (None, 2000, 16)     0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 2000, 16)     0           spatial_dropout1d[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 2000, 16)     2320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 2000, 16)     64          conv1d_1[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_1 (SpatialDro (None, 2000, 16)     0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 2000, 16)     0           spatial_dropout1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 1000, 16)     0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 1000, 32)     4640        max_pooling1d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 1000, 32)     128         conv1d_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_2 (SpatialDro (None, 1000, 32)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1000, 32)     0           spatial_dropout1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 1000, 32)     9248        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 1000, 32)     128         conv1d_3[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_3 (SpatialDro (None, 1000, 32)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 1000, 32)     0           spatial_dropout1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 500, 32)      0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 500, 64)      18496       max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 500, 64)      256         conv1d_4[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_4 (SpatialDro (None, 500, 64)      0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 500, 64)      0           spatial_dropout1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 500, 64)      36928       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 500, 64)      256         conv1d_5[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_5 (SpatialDro (None, 500, 64)      0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 500, 64)      0           spatial_dropout1d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 250, 64)      0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 250, 128)     73856       max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 250, 128)     512         conv1d_6[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_6 (SpatialDro (None, 250, 128)     0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 250, 128)     0           spatial_dropout1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 250, 128)     147584      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 250, 128)     512         conv1d_7[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_7 (SpatialDro (None, 250, 128)     0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 250, 128)     0           spatial_dropout1d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 125, 128)     0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 125, 256)     295168      max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 125, 256)     1024        conv1d_8[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_8 (SpatialDro (None, 125, 256)     0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 125, 256)     0           spatial_dropout1d_8[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 125, 256)     590080      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 125, 256)     1024        conv1d_9[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_9 (SpatialDro (None, 125, 256)     0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 125, 256)     0           spatial_dropout1d_9[0][0]
# __________________________________________________________________________________________________
# conv1d_transpose (Conv1DTranspo (None, 250, 128)     262272      activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 250, 256)     0           conv1d_transpose[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 250, 128)     295040      concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 250, 128)     512         conv1d_10[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_10 (SpatialDr (None, 250, 128)     0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 250, 128)     0           spatial_dropout1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 250, 128)     147584      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 250, 128)     512         conv1d_11[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_11 (SpatialDr (None, 250, 128)     0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 250, 128)     0           spatial_dropout1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_transpose_1 (Conv1DTrans (None, 500, 64)      65600       activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 500, 128)     0           conv1d_transpose_1[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 500, 64)      73792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 500, 64)      256         conv1d_12[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_12 (SpatialDr (None, 500, 64)      0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 500, 64)      0           spatial_dropout1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 500, 64)      36928       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 500, 64)      256         conv1d_13[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_13 (SpatialDr (None, 500, 64)      0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 500, 64)      0           spatial_dropout1d_13[0][0]
# __________________________________________________________________________________________________
# conv1d_transpose_2 (Conv1DTrans (None, 1000, 32)     16416       activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 1000, 64)     0           conv1d_transpose_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 1000, 32)     18464       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 1000, 32)     128         conv1d_14[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_14 (SpatialDr (None, 1000, 32)     0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 1000, 32)     0           spatial_dropout1d_14[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 1000, 32)     9248        activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 1000, 32)     128         conv1d_15[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_15 (SpatialDr (None, 1000, 32)     0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 1000, 32)     0           spatial_dropout1d_15[0][0]
# __________________________________________________________________________________________________
# conv1d_transpose_3 (Conv1DTrans (None, 2000, 16)     4112        activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 2000, 32)     0           conv1d_transpose_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 2000, 16)     4624        concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 2000, 16)     64          conv1d_16[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_16 (SpatialDr (None, 2000, 16)     0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 2000, 16)     0           spatial_dropout1d_16[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 2000, 16)     2320        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 2000, 16)     64          conv1d_17[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_17 (SpatialDr (None, 2000, 16)     0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 2000, 16)     0           spatial_dropout1d_17[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 2000, 4)      68          activation_17[0][0]
# ==================================================================================================
# Total params: 2,122,420
# Trainable params: 2,119,476
# Non-trainable params: 2,944
# __________________________________________________________________________________________________
# Epoch 1/2000
# 5/5 [==============================] - 26s 3s/step - loss: 0.7265 - Jaccard: 0.1621 - f1_score: 0.2766 - val_loss: 0.8868 - val_Jaccard: 0.0664 - val_f1_score: 0.1236
#
# Epoch 00001: val_f1_score improved from -inf to 0.12363, saving model to weights.h5
# Epoch 2/2000
# 5/5 [==============================] - 1s 166ms/step - loss: 0.5715 - Jaccard: 0.2777 - f1_score: 0.4303 - val_loss: 0.9072 - val_Jaccard: 0.0472 - val_f1_score: 0.0890
#
# Epoch 00002: val_f1_score did not improve from 0.12363
# Epoch 3/2000
# 5/5 [==============================] - 1s 165ms/step - loss: 0.4708 - Jaccard: 0.3666 - f1_score: 0.5300 - val_loss: 0.9073 - val_Jaccard: 0.0473 - val_f1_score: 0.0891
#
# Epoch 00003: val_f1_score did not improve from 0.12363
# Epoch 4/2000
# 5/5 [==============================] - 1s 164ms/step - loss: 0.4201 - Jaccard: 0.4165 - f1_score: 0.5807 - val_loss: 0.9003 - val_Jaccard: 0.0533 - val_f1_score: 0.0996
#
# Epoch 00004: val_f1_score did not improve from 0.12363
# Epoch 5/2000
# 5/5 [==============================] - 1s 163ms/step - loss: 0.3807 - Jaccard: 0.4575 - f1_score: 0.6198 - val_loss: 0.9036 - val_Jaccard: 0.0502 - val_f1_score: 0.0943
#
# Epoch 00005: val_f1_score did not improve from 0.12363
# Epoch 6/2000
# 5/5 [==============================] - 1s 165ms/step - loss: 0.3395 - Jaccard: 0.5034 - f1_score: 0.6614 - val_loss: 0.9030 - val_Jaccard: 0.0492 - val_f1_score: 0.0926
#
# Epoch 00006: val_f1_score did not improve from 0.12363
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 7/2000
# 5/5 [==============================] - 1s 165ms/step - loss: 0.3075 - Jaccard: 0.5400 - f1_score: 0.6927 - val_loss: 0.8799 - val_Jaccard: 0.0570 - val_f1_score: 0.1062
#
# Epoch 00007: val_f1_score did not improve from 0.12363
# Epoch 8/2000
# 5/5 [==============================] - 1s 165ms/step - loss: 0.2901 - Jaccard: 0.5611 - f1_score: 0.7105 - val_loss: 0.8712 - val_Jaccard: 0.0599 - val_f1_score: 0.1109
#
# Epoch 00008: val_f1_score did not improve from 0.12363
# Epoch 9/2000
# 5/5 [==============================] - 1s 163ms/step - loss: 0.2672 - Jaccard: 0.5898 - f1_score: 0.7341 - val_loss: 0.8470 - val_Jaccard: 0.0689 - val_f1_score: 0.1258
#
# Epoch 00009: val_f1_score improved from 0.12363 to 0.12577, saving model to weights.h5
# Epoch 10/2000
# 5/5 [==============================] - 1s 163ms/step - loss: 0.2555 - Jaccard: 0.6038 - f1_score: 0.7453 - val_loss: 0.7407 - val_Jaccard: 0.1312 - val_f1_score: 0.2265
#
# Epoch 00010: val_f1_score improved from 0.12577 to 0.22653, saving model to weights.h5
# Epoch 11/2000
# 5/5 [==============================] - 1s 162ms/step - loss: 0.2333 - Jaccard: 0.6308 - f1_score: 0.7663 - val_loss: 0.6773 - val_Jaccard: 0.1778 - val_f1_score: 0.2966
#
# Epoch 00011: val_f1_score improved from 0.22653 to 0.29656, saving model to weights.h5
# Epoch 12/2000
# 5/5 [==============================] - 1s 163ms/step - loss: 0.2275 - Jaccard: 0.6392 - f1_score: 0.7725 - val_loss: 0.6262 - val_Jaccard: 0.2110 - val_f1_score: 0.3417
#
# Epoch 00012: val_f1_score improved from 0.29656 to 0.34173, saving model to weights.h5
# Epoch 13/2000
# 5/5 [==============================] - 1s 164ms/step - loss: 0.2162 - Jaccard: 0.6554 - f1_score: 0.7846 - val_loss: 0.5065 - val_Jaccard: 0.2964 - val_f1_score: 0.4491
#
# Epoch 00013: val_f1_score improved from 0.34173 to 0.44915, saving model to weights.h5
# Epoch 14/2000
# 5/5 [==============================] - 1s 164ms/step - loss: 0.2023 - Jaccard: 0.6729 - f1_score: 0.7974 - val_loss: 0.3371 - val_Jaccard: 0.4705 - val_f1_score: 0.6358
#
# Epoch 00014: val_f1_score improved from 0.44915 to 0.63576, saving model to weights.h5
# Epoch 15/2000
# 5/5 [==============================] - 1s 164ms/step - loss: 0.1941 - Jaccard: 0.6850 - f1_score: 0.8062 - val_loss: 0.2821 - val_Jaccard: 0.5368 - val_f1_score: 0.6952
#
# Epoch 00015: val_f1_score improved from 0.63576 to 0.69519, saving model to weights.h5
# Epoch 16/2000
# 5/5 [==============================] - 1s 165ms/step - loss: 0.1888 - Jaccard: 0.6919 - f1_score: 0.8114 - val_loss: 0.2521 - val_Jaccard: 0.5811 - val_f1_score: 0.7318
#
# Epoch 00016: val_f1_score improved from 0.69519 to 0.73176, saving model to weights.h5
# Epoch 17/2000
# 5/5 [==============================] - 1s 164ms/step - loss: 0.1812 - Jaccard: 0.7030 - f1_score: 0.8189 - val_loss: 0.2107 - val_Jaccard: 0.6357 - val_f1_score: 0.7726
#
# Epoch 00017: val_f1_score improved from 0.73176 to 0.77258, saving model to weights.h5
# Epoch 18/2000
# 5/5 [==============================] - 1s 165ms/step - loss: 0.1720 - Jaccard: 0.7169 - f1_score: 0.8290 - val_loss: 0.1812 - val_Jaccard: 0.6740 - val_f1_score: 0.8016
#
# Epoch 00018: val_f1_score improved from 0.77258 to 0.80161, saving model to weights.h5
# Epoch 19/2000
# 5/5 [==============================] - 1s 163ms/step - loss: 0.1624 - Jaccard: 0.7294 - f1_score: 0.8378 - val_loss: 0.1422 - val_Jaccard: 0.7384 - val_f1_score: 0.8470
#
# Epoch 00019: val_f1_score improved from 0.80161 to 0.84696, saving model to weights.h5
# Epoch 20/2000
# 5/5 [==============================] - 1s 164ms/step - loss: 0.1606 - Jaccard: 0.7311 - f1_score: 0.8392 - val_loss: 0.1254 - val_Jaccard: 0.7615 - val_f1_score: 0.8620
#
# Epoch 00020: val_f1_score improved from 0.84696 to 0.86204, saving model to weights.h5
# Epoch 21/2000
# 5/5 [==============================] - 1s 165ms/step - loss: 0.1555 - Jaccard: 0.7403 - f1_score: 0.8452 - val_loss: 0.1247 - val_Jaccard: 0.7676 - val_f1_score: 0.8658
#
# Epoch 00021: val_f1_score improved from 0.86204 to 0.86582, saving model to weights.h5
# Epoch 22/2000
# 5/5 [==============================] - 1s 164ms/step - loss: 0.1481 - Jaccard: 0.7499 - f1_score: 0.8521 - val_loss: 0.1193 - val_Jaccard: 0.7817 - val_f1_score: 0.8750
#
# Epoch 00022: val_f1_score improved from 0.86582 to 0.87497, saving model to weights.h5
# Epoch 23/2000
# 5/5 [==============================] - 1s 164ms/step - loss: 0.1409 - Jaccard: 0.7607 - f1_score: 0.8594 - val_loss: 0.1124 - val_Jaccard: 0.7929 - val_f1_score: 0.8820
#
# Epoch 00023: val_f1_score improved from 0.87497 to 0.88203, saving model to weights.h5
# Epoch 24/2000
# 5/5 [==============================] - 1s 165ms/step - loss: 0.1412 - Jaccard: 0.7608 - f1_score: 0.8595 - val_loss: 0.1093 - val_Jaccard: 0.7973 - val_f1_score: 0.8848
#
# Epoch 00024: val_f1_score improved from 0.88203 to 0.88484, saving model to weights.h5
# Epoch 25/2000
# 5/5 [==============================] - 1s 165ms/step - loss: 0.1365 - Jaccard: 0.7657 - f1_score: 0.8634 - val_loss: 0.1077 - val_Jaccard: 0.8021 - val_f1_score: 0.8877
#
# Epoch 00025: val_f1_score improved from 0.88484 to 0.88770, saving model to weights.h5
# Epoch 26/2000
# 5/5 [==============================] - 1s 163ms/step - loss: 0.1349 - Jaccard: 0.7688 - f1_score: 0.8649 - val_loss: 0.1028 - val_Jaccard: 0.8141 - val_f1_score: 0.8952
#
# Epoch 00026: val_f1_score improved from 0.88770 to 0.89523, saving model to weights.h5
# Epoch 27/2000
# 5/5 [==============================] - 1s 166ms/step - loss: 0.1296 - Jaccard: 0.7773 - f1_score: 0.8706 - val_loss: 0.0975 - val_Jaccard: 0.8223 - val_f1_score: 0.9005
#
# Epoch 00027: val_f1_score improved from 0.89523 to 0.90046, saving model to weights.h5
# Epoch 28/2000
# 5/5 [==============================] - 1s 163ms/step - loss: 0.1289 - Jaccard: 0.7784 - f1_score: 0.8713 - val_loss: 0.0956 - val_Jaccard: 0.8276 - val_f1_score: 0.9034
#
# Epoch 00028: val_f1_score improved from 0.90046 to 0.90341, saving model to weights.h5
# Epoch 29/2000
# 5/5 [==============================] - 1s 162ms/step - loss: 0.1277 - Jaccard: 0.7797 - f1_score: 0.8722 - val_loss: 0.0945 - val_Jaccard: 0.8272 - val_f1_score: 0.9032
#
# Epoch 00029: val_f1_score did not improve from 0.90341
# Epoch 30/2000
# 5/5 [==============================] - 1s 164ms/step - loss: 0.1258 - Jaccard: 0.7830 - f1_score: 0.8744 - val_loss: 0.0933 - val_Jaccard: 0.8294 - val_f1_score: 0.9045
#
# Epoch 00030: val_f1_score improved from 0.90341 to 0.90448, saving model to weights.h5
# Epoch 31/2000
# 5/5 [==============================] - 1s 164ms/step - loss: 0.1223 - Jaccard: 0.7882 - f1_score: 0.8778 - val_loss: 0.0954 - val_Jaccard: 0.8283 - val_f1_score: 0.9038
#
# Epoch 00031: val_f1_score did not improve from 0.90448
# Epoch 32/2000
# 5/5 [==============================] - 1s 165ms/step - loss: 0.1200 - Jaccard: 0.7920 - f1_score: 0.8803 - val_loss: 0.0942 - val_Jaccard: 0.8294 - val_f1_score: 0.9045
#
# Epoch 00032: val_f1_score improved from 0.90448 to 0.90450, saving model to weights.h5
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Epoch 33/2000
# 5/5 [==============================] - 1s 164ms/step - loss: 0.1217 - Jaccard: 0.7899 - f1_score: 0.8784 - val_loss: 0.0939 - val_Jaccard: 0.8288 - val_f1_score: 0.9041
#
# Epoch 00033: val_f1_score did not improve from 0.90450
# Epoch 34/2000
# 5/5 [==============================] - 1s 165ms/step - loss: 0.1161 - Jaccard: 0.7971 - f1_score: 0.8838 - val_loss: 0.0930 - val_Jaccard: 0.8306 - val_f1_score: 0.9051
#
# Epoch 00034: val_f1_score improved from 0.90450 to 0.90514, saving model to weights.h5
# Epoch 35/2000
# 5/5 [==============================] - 1s 164ms/step - loss: 0.1130 - Jaccard: 0.8019 - f1_score: 0.8869 - val_loss: 0.0925 - val_Jaccard: 0.8314 - val_f1_score: 0.9055
#
# Epoch 00035: val_f1_score improved from 0.90514 to 0.90553, saving model to weights.h5
# Epoch 36/2000
# 5/5 [==============================] - 1s 164ms/step - loss: 0.1136 - Jaccard: 0.8016 - f1_score: 0.8866 - val_loss: 0.0921 - val_Jaccard: 0.8317 - val_f1_score: 0.9058
#
# Epoch 00036: val_f1_score improved from 0.90553 to 0.90576, saving model to weights.h5
# Epoch 37/2000
# 5/5 [==============================] - 1s 165ms/step - loss: 0.1144 - Jaccard: 0.8001 - f1_score: 0.8857 - val_loss: 0.0906 - val_Jaccard: 0.8351 - val_f1_score: 0.9079
#
# Epoch 00037: val_f1_score improved from 0.90576 to 0.90788, saving model to weights.h5
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 38/2000
# 5/5 [==============================] - 1s 164ms/step - loss: 0.1123 - Jaccard: 0.8037 - f1_score: 0.8880 - val_loss: 0.0901 - val_Jaccard: 0.8354 - val_f1_score: 0.9081
#
# Epoch 00038: val_f1_score improved from 0.90788 to 0.90806, saving model to weights.h5
# Epoch 39/2000
# 5/5 [==============================] - 1s 164ms/step - loss: 0.1086 - Jaccard: 0.8086 - f1_score: 0.8912 - val_loss: 0.0897 - val_Jaccard: 0.8371 - val_f1_score: 0.9091
#
# Epoch 00039: val_f1_score improved from 0.90806 to 0.90911, saving model to weights.h5
# Epoch 40/2000
# 5/5 [==============================] - 1s 164ms/step - loss: 0.1084 - Jaccard: 0.8086 - f1_score: 0.8914 - val_loss: 0.0898 - val_Jaccard: 0.8376 - val_f1_score: 0.9094
#
# Epoch 00040: val_f1_score improved from 0.90911 to 0.90944, saving model to weights.h5
# Epoch 41/2000
# 5/5 [==============================] - 1s 165ms/step - loss: 0.1110 - Jaccard: 0.8054 - f1_score: 0.8889 - val_loss: 0.0887 - val_Jaccard: 0.8398 - val_f1_score: 0.9107
#
# Epoch 00041: val_f1_score improved from 0.90944 to 0.91073, saving model to weights.h5
# Epoch 42/2000
# 5/5 [==============================] - 1s 165ms/step - loss: 0.1105 - Jaccard: 0.8060 - f1_score: 0.8895 - val_loss: 0.0878 - val_Jaccard: 0.8405 - val_f1_score: 0.9112
#
# Epoch 00042: val_f1_score improved from 0.91073 to 0.91119, saving model to weights.h5
# Epoch 43/2000
# 5/5 [==============================] - 1s 165ms/step - loss: 0.1089 - Jaccard: 0.8086 - f1_score: 0.8911 - val_loss: 0.0866 - val_Jaccard: 0.8427 - val_f1_score: 0.9126
#
# Epoch 00043: val_f1_score improved from 0.91119 to 0.91255, saving model to weights.h5
# Epoch 44/2000
# 5/5 [==============================] - 1s 165ms/step - loss: 0.1095 - Jaccard: 0.8085 - f1_score: 0.8908 - val_loss: 0.0856 - val_Jaccard: 0.8446 - val_f1_score: 0.9137
#
# Epoch 00044: val_f1_score improved from 0.91255 to 0.91375, saving model to weights.h5
# Epoch 45/2000
# 5/5 [==============================] - 1s 163ms/step - loss: 0.1089 - Jaccard: 0.8094 - f1_score: 0.8915 - val_loss: 0.0856 - val_Jaccard: 0.8454 - val_f1_score: 0.9143
#
# Epoch 00045: val_f1_score improved from 0.91375 to 0.91427, saving model to weights.h5
# Epoch 46/2000
# 5/5 [==============================] - 1s 164ms/step - loss: 0.1067 - Jaccard: 0.8116 - f1_score: 0.8932 - val_loss: 0.0858 - val_Jaccard: 0.8462 - val_f1_score: 0.9148
#
# Epoch 00046: val_f1_score improved from 0.91427 to 0.91479, saving model to weights.h5
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Epoch 47/2000
# 5/5 [==============================] - 1s 167ms/step - loss: 0.1108 - Jaccard: 0.8059 - f1_score: 0.8889 - val_loss: 0.0853 - val_Jaccard: 0.8482 - val_f1_score: 0.9160
#
# Epoch 00047: val_f1_score improved from 0.91479 to 0.91602, saving model to weights.h5
# Epoch 48/2000
# 5/5 [==============================] - 1s 167ms/step - loss: 0.1045 - Jaccard: 0.8148 - f1_score: 0.8955 - val_loss: 0.0854 - val_Jaccard: 0.8477 - val_f1_score: 0.9157
#
# Epoch 00048: val_f1_score did not improve from 0.91602
# Epoch 49/2000
# 5/5 [==============================] - 1s 167ms/step - loss: 0.1059 - Jaccard: 0.8127 - f1_score: 0.8941 - val_loss: 0.0851 - val_Jaccard: 0.8478 - val_f1_score: 0.9158
#
# Epoch 00049: val_f1_score did not improve from 0.91602
# Epoch 50/2000
# 5/5 [==============================] - 1s 165ms/step - loss: 0.1074 - Jaccard: 0.8107 - f1_score: 0.8925 - val_loss: 0.0848 - val_Jaccard: 0.8484 - val_f1_score: 0.9162
#
# Epoch 00050: val_f1_score improved from 0.91602 to 0.91618, saving model to weights.h5
# Epoch 51/2000
# 5/5 [==============================] - 1s 164ms/step - loss: 0.1049 - Jaccard: 0.8143 - f1_score: 0.8950 - val_loss: 0.0850 - val_Jaccard: 0.8480 - val_f1_score: 0.9159
#
# Epoch 00051: val_f1_score did not improve from 0.91618
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 52/2000
# 5/5 [==============================] - 1s 165ms/step - loss: 0.1074 - Jaccard: 0.8108 - f1_score: 0.8926 - val_loss: 0.0848 - val_Jaccard: 0.8485 - val_f1_score: 0.9162
#
# Epoch 00052: val_f1_score improved from 0.91618 to 0.91620, saving model to weights.h5
# Epoch 53/2000
# 5/5 [==============================] - 1s 165ms/step - loss: 0.1088 - Jaccard: 0.8086 - f1_score: 0.8910 - val_loss: 0.0846 - val_Jaccard: 0.8486 - val_f1_score: 0.9163
#
# Epoch 00053: val_f1_score improved from 0.91620 to 0.91631, saving model to weights.h5
# Epoch 54/2000
# 5/5 [==============================] - 1s 166ms/step - loss: 0.1084 - Jaccard: 0.8097 - f1_score: 0.8918 - val_loss: 0.0844 - val_Jaccard: 0.8473 - val_f1_score: 0.9156
#
# Epoch 00054: val_f1_score did not improve from 0.91631
# Epoch 55/2000
# 5/5 [==============================] - 1s 165ms/step - loss: 0.1039 - Jaccard: 0.8163 - f1_score: 0.8961 - val_loss: 0.0840 - val_Jaccard: 0.8483 - val_f1_score: 0.9162
#
# Epoch 00055: val_f1_score did not improve from 0.91631
# Epoch 56/2000
# 5/5 [==============================] - 1s 165ms/step - loss: 0.1055 - Jaccard: 0.8151 - f1_score: 0.8946 - val_loss: 0.0836 - val_Jaccard: 0.8495 - val_f1_score: 0.9169
#
# Epoch 00056: val_f1_score improved from 0.91631 to 0.91691, saving model to weights.h5
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 57/2000
# 5/5 [==============================] - 1s 165ms/step - loss: 0.1042 - Jaccard: 0.8155 - f1_score: 0.8956 - val_loss: 0.0834 - val_Jaccard: 0.8505 - val_f1_score: 0.9175
#
# Epoch 00057: val_f1_score improved from 0.91691 to 0.91754, saving model to weights.h5
# Epoch 00057: early stopping

# %% [markdown]
# ### Inference

# %%
valid = [np.load("valid_x.npy"), np.load("valid_y.npy")]
print(valid[0].shape)

Predict(test=valid)
# Out:
# (285, 2000, 12)
